# %%
import findspark
findspark.init()
import pyspark 
from pyspark.sql import SparkSession
spark = SparkSession \
    .builder \
    .appName("teste") \
    .getOrCreate()

# %%
import os
import pandas as pd 

filepath = "C:/Users/Dell/Desktop/teste_pjus/"
filelist = os.listdir(filepath)
#print(filepath)
#print(filelist)

for f in filelist:
    print(f)
    print('oi') #para testes
# for f in filelist:

    df = spark.read.csv(f)
    df.show()
# Out:
# INMET_CO_DF_A001_BRASILIA_01-01-2021_A_31-12-2021.CSV
# oi
# +--------------------+
# |                 _c0|
# +--------------------+
# |          REGIAO:;CO|
# |              UF:;DF|
# |   ESTACAO:;BRASILIA|
# |  CODIGO (WMO):;A001|
# |       LATITUDE:;-15|
# |      LONGITUDE:;-47|
# |      ALTITUDE:;1160|
# |DATA DE FUNDACAO:...|
# |Data;Hora UTC;PRE...|
# |2021/01/01;0000 U...|
# |2021/01/01;0100 U...|
# |2021/01/01;0200 U...|
# |2021/01/01;0300 U...|
# |2021/01/01;0400 U...|
# |2021/01/01;0500 U...|
# |2021/01/01;0600 U...|
# |2021/01/01;0700 U...|
# |2021/01/01;0800 U...|
# |2021/01/01;0900 U...|
# |2021/01/01;1000 U...|
# +--------------------+
# only showing top 20 rows
#
# INMET_CO_DF_A042_BRAZLANDIA_01-01-2021_A_31-12-2021.CSV
# oi
# +--------------------+
# |                 _c0|
# +--------------------+
# |          REGIAO:;CO|
# |              UF:;DF|
# | ESTACAO:;BRAZLANDIA|
# |  CODIGO (WMO):;A042|
# |       LATITUDE:;-15|
# |      LONGITUDE:;-48|
# ...

# %%
import os
import pandas as pd 

filepath = "C:/Users/Dell/Desktop/teste_pjus/"
filelist = os.listdir(filepath)
#filelist

#print(filelist)

for f in filelist:

    df = spark.read.csv(f)
    df.show()
# for file in path_teste:
#     print(file)
#     #df = spark.read.csv(file)
#     df = pd.read_csv(file)

# df_append = pd.DataFrame()
# #append all files together
# for file in filelist:
#             print(file)
#             df_temp = pd.read_csv(file)
#             df_append = df_append.append(df_temp, ignore_index=True)
# # df_append

# df_concat = pd.concat([pd.read_csv(file, header=None, sep=";") for file in filelist ], ignore_index=True)
# df_concat
